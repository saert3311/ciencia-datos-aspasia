# %%
import pandas as pd

import warnings
TRAIN_URL = 'https://raw.githubusercontent.com/natjulian/Contribuci-n-Diplomado-Data-Science-UC-2021/main/Bases%20de%20datos%20Clases/Activity/train.csv'
TEST_URL =  'https://raw.githubusercontent.com/natjulian/Contribuci-n-Diplomado-Data-Science-UC-2021/main/Bases%20de%20datos%20Clases/Activity/test.csv'

df_train = pd.read_csv(TRAIN_URL)
df_test = pd.read_csv(TEST_URL)

# %%
df_train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X
# 0           0.288585          -0.020294          -0.132905         -0.995279  \
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y
# 0         -0.983111         -0.913526         -0.995112         -0.983185  \
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %% [markdown]
# Cargue los set de datos de entrenamiento y prueba. ¿Cuáles son las
# dimensiones de estos set de datos?

# %%
print('Dimension de df train', df_train.shape)
print('Dimension de df test', df_test.shape)
# Out:
# Dimension de df train (7352, 563)
# Dimension de df test (2947, 563)

# %% [markdown]
# 2. Estudie la cantidad de registros que hay en cada actividad en el set de
# entrenamiento. Para esto, una opción es utilizar la función de pandas
# crosstab(index=columna, columns="count"). ¿Cómo se encuentran
# repartidas las Actividades? ¿Existe algún desbalance en las categorías?
# (realice un gráfico que acompañe su análisis) Comente.
